# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# استدعاء المكاتب اللازمة
import pandas as pd
from collections import defaultdict
from itertools import combinations
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

from mlxtend.frequent_patterns import apriori, association_rules

import seaborn as sns

# %%
# تحميل البيانات
x_train_file_path = '/content/drive/MyDrive/data/x_train.csv'
# x_train = pd.read_csv(x_train_file_path)  # ميزات التدريب

# file_path = '/content/drive/MyDrive/data/y_train.csv'
# y_train = pd.read_csv(file_path)  # تسميات التدريب

# file_path = '/content/drive/MyDrive/data/x_test.csv'
# x_test = pd.read_csv(file_path)    # ميزات الاختبار

# file_path = '/content/drive/MyDrive/data/y_test.csv'
# y_test = pd.read_csv(file_path)    # تسميات الاختبار

# file_path = '/content/drive/MyDrive/data/total.csv'
# total = pd.read_csv(file_path)       # مجموعة البيانات الكاملة

# file_path = '/content/drive/MyDrive/data/norm.csv'
# norm = pd.read_csv(file_path)         # البيانات الطبيعية

# file_path = '/content/drive/MyDrive/data/anom.csv'
# anom = pd.read_csv(file_path)         # البيانات غير الطبيعية

#طباعة بيانات
#print(x_train.info())
#print("************#################***************")
#print(x_test.info())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#كلاس مخصص لتحميل وتحويل المعاملات من الصفوف الموجودة في ملف قاعدة البيانات
class Transactions:
    def __init__(self):
        self.Transactions = []

    def load_transactions(self, file_path):
        df = pd.read_csv(file_path)
        for index, row in df.iterrows():
            try:
                temp = frozenset(map(lambda x: int(float(x)), row.astype(str).values))
                self.Transactions.append(temp)
            except ValueError as e:
                print(f"Error processing row {index}: {e}")

        # طباعة المعاملات المحملة
        print("تم تحميل المعاملات:")
        for transaction in self.Transactions:
            print(transaction)

# هنا تقوم بإنشاء كائن من الفئة
transactions_object = Transactions()

# هنا تستدعي الدالة مع المسار
transactions_object.load_transactions(x_train_file_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Streaming output truncated to the last 5000 lines.
# frozenset({0, 1, 2, 5, 8, 51, 52, 57, 61})
# frozenset({0, 1, 5, 38, 8, 13, 240, 49, 178})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 5, 9, 52})
# frozenset({0, 2, 259, 5, 38, 8, 13, 50, 182, 247})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 4, 8, 52})
# frozenset({0, 1, 2, 5, 11, 61})
# frozenset({0, 1, 160, 5, 38, 8, 13, 49, 221})
# frozenset({0, 2, 5, 262, 8, 41, 13, 50, 183, 250})
# frozenset({0, 1, 5, 70, 8, 9, 48, 50})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 70, 8, 9, 48, 50})
# frozenset({0, 2, 36, 5, 263, 8, 13, 49, 251, 189})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 2, 4, 9, 42})
# frozenset({0, 1, 5, 9, 51})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 2, 5, 8, 17, 24, 57})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 5, 8, 40, 13, 175, 241, 50, 253})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 32, 3, 5, 8, 42, 47})
# frozenset({0, 33, 2, 67, 5, 8, 110, 114, 52})
# frozenset({0, 2, 68, 5, 8, 9, 72, 50, 52})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 2, 5, 71, 8, 9, 75, 48, 52})
# frozenset({0, 1, 5, 8, 77, 48, 20, 127})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 3, 5, 38, 8, 47, 24})
# frozenset({0, 1, 6, 45, 23})
# frozenset({0, 1, 2, 5, 8, 43})
# frozenset({0, 1, 5, 69, 8, 9, 48})
# frozenset({0, 2, 3, 5, 6, 39, 8, 41, 47, 29})
# frozenset({0, 2, 5, 8, 47, 52, 54, 58})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 66, 2, 5, 12})
# frozenset({0, 2, 5, 70, 8, 74, 48, 52})
# frozenset({0, 2, 3, 5, 37, 39, 8, 47, 29})
# frozenset({0, 1, 5, 8, 14, 48, 22})
# frozenset({0, 193, 2, 260, 5, 39, 8, 13, 272, 50})
# frozenset({0, 2, 3, 5, 8, 107, 109, 47, 20, 61})
# frozenset({0, 1, 67, 5, 294, 8, 200, 13, 50})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 5, 197, 8, 13, 47, 50, 280})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 6, 8, 49, 52, 61})
# frozenset({0, 1, 5, 38, 8, 13, 50, 242, 179})
# frozenset({0, 2, 5, 38, 8, 235, 172, 13, 50, 247})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 10, 62})
# frozenset({0, 2, 35, 5, 230, 8, 172, 13, 50, 242})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 2, 5, 71, 8, 9, 75, 48, 51})
# frozenset({0, 1, 2, 5, 9, 47})
# frozenset({0, 1, 5, 8, 43, 203, 13, 270, 50})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 2, 36, 5, 8, 11, 48, 62})
# frozenset({0, 1, 5, 9, 51})
# frozenset({0, 2, 5, 198, 8, 42, 13, 49, 273, 285})
# frozenset({0, 1, 4, 6, 23})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 5, 8, 51, 52, 59, 63})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 67, 5, 7, 8, 71, 48, 51})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 41, 13, 176, 241, 50})
# frozenset({0, 1, 5, 7, 43})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 9, 49, 52, 63})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 64, 2, 68, 5, 7, 8, 48})
# frozenset({0, 1, 32, 68, 5, 8, 48, 115})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 4, 8, 51})
# frozenset({0, 1, 5, 39, 8, 13, 50, 184, 251})
# frozenset({0, 1, 5, 9, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 43, 171, 237, 13, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 229, 8, 40, 168, 13, 49})
# frozenset({0, 1, 2, 5, 10, 48})
# frozenset({0, 1, 4, 7, 46})
# frozenset({0, 1, 163, 5, 230, 8, 42, 13, 50})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 2, 164, 5, 37, 8, 235, 13, 49, 223})
# frozenset({0, 2, 3, 5, 8, 47, 16, 49, 51, 23})
# frozenset({0, 1, 5, 8, 52, 59})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 3, 5, 8, 107, 47, 20, 61})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 256, 5, 8, 40, 13, 50, 190})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 3, 5, 6, 39, 8, 47, 29})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 2, 5, 39, 8, 266, 13, 50, 190, 254})
# frozenset({0, 2, 66, 5, 70, 8, 48})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 4, 9, 60})
# frozenset({0, 1, 2, 5, 10, 51})
# frozenset({0, 2, 67, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 5, 229, 166, 8, 40, 13, 49})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 1, 5, 8, 41, 79, 57, 28})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 256, 2, 5, 37, 8, 13, 50, 244, 182})
# frozenset({0, 1, 5, 8, 43, 13, 173, 240, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 3, 36, 5, 8, 12, 47, 57, 59})
# frozenset({0, 65, 2, 1, 32, 5, 8, 48, 27})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 201, 43, 13, 50, 274})
# frozenset({0, 1, 4, 6, 23})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 1, 5, 71, 8, 10, 48, 50})
# frozenset({0, 1, 5, 8, 12, 57, 30})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 2, 5, 8, 50, 52, 56, 60})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 36, 5, 8, 13, 49, 247, 186})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 32, 2, 3, 5, 8, 42, 44, 47})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 5, 70, 8, 74, 48, 51})
# frozenset({0, 256, 2, 5, 8, 43, 268, 13, 49, 186})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 33, 5, 6})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 2, 5, 8, 48, 54, 27, 94})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 36, 5, 70, 8, 57, 26})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 2, 3, 5, 8, 57})
# frozenset({0, 1, 4, 7, 52})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 9, 52})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 3, 5, 8, 46, 52, 57, 61})
# frozenset({0, 1, 4, 37, 7})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 39, 8, 13, 50, 181, 248})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 2, 3, 5, 6, 39, 8, 41, 47, 29})
# frozenset({0, 1, 5, 9, 55})
# frozenset({0, 2, 35, 3, 5, 4, 37, 8, 47, 28})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 67, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 67, 5, 7, 8, 71, 48, 51})
# frozenset({0, 1, 33, 5, 6})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 6, 8, 45, 52, 56})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 5, 70, 8, 74, 48, 52})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 2, 3, 5, 39, 8, 41, 47, 31})
# frozenset({0, 2, 66, 5, 8, 10, 46, 52, 62})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 3, 5, 39, 8, 234, 13, 173, 50, 246})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 2, 3, 5, 8, 57})
# frozenset({0, 1, 3, 5, 8, 48, 52, 56})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 5, 7, 42})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 2, 3, 5, 6, 39, 8, 41, 47, 29})
# frozenset({0, 1, 2, 3, 4, 5, 8, 9, 57})
# frozenset({0, 1, 5, 8, 13, 45, 50, 157, 223})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 43})
# frozenset({0, 1, 5, 37, 8, 13, 238, 49, 177})
# frozenset({0, 1, 35, 5, 8, 13, 239, 49, 182})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 65, 2, 5, 69, 8, 48})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 50, 52, 56})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 96, 2, 3, 5, 8, 47, 16, 59, 94})
# frozenset({0, 1, 5, 8, 14, 48, 22})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 35, 5, 8, 237, 13, 49, 180})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 300, 13, 48, 50, 215})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 2, 5, 199, 8, 266, 42, 13, 49, 278})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 2, 66, 4, 5, 8, 51, 52, 62})
# frozenset({0, 2, 260, 5, 8, 41, 13, 49, 181, 248})
# frozenset({0, 2, 5, 71, 8, 10, 75, 48, 50})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 97, 5, 8, 48, 57, 28})
# frozenset({0, 1, 4, 5, 8, 49, 52, 59})
# frozenset({0, 1, 4, 5, 8, 49, 52, 60})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 69, 8, 48, 52})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 41, 13, 238, 173, 49})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 13, 46, 50, 178, 255})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 3, 5, 8, 50, 52, 59})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 4, 5, 25})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 5, 6, 8, 49, 52, 61})
# frozenset({0, 32, 2, 3, 4, 5, 8, 41, 43, 47})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 169, 44, 13, 238, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 9, 12, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 13, 302, 49, 221})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 5, 230, 37, 8, 170, 13, 50, 242})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 2, 162, 5, 8, 41, 235, 13, 50, 223})
# frozenset({0, 1, 5, 70, 8, 48, 52})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 231, 8, 39, 169, 13, 50})
# frozenset({0, 1, 5, 38, 8, 13, 50, 188, 254})
# frozenset({0, 1, 32, 3, 5, 6, 8, 44, 47})
# frozenset({0, 1, 5, 39, 8, 236, 13, 172, 49})
# frozenset({0, 1, 5, 9, 55})
# frozenset({0, 32, 2, 3, 5, 8, 42, 44, 47})
# frozenset({0, 1, 2, 5, 8, 52, 58, 62})
# frozenset({0, 1, 98, 3, 33, 5, 8, 47, 54})
# frozenset({0, 32, 2, 5, 8, 233, 300, 13, 49, 312})
# frozenset({0, 1, 2, 5, 8, 52, 53, 60})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 1, 3, 5, 8, 41, 47, 31})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 40, 13, 50, 248, 184})
# frozenset({0, 1, 5, 8, 44, 13, 49, 181, 250})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 64, 5, 8, 47, 48})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 68, 5, 8, 72, 52, 55})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 2, 259, 5, 8, 40, 13, 49, 181, 247})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 2, 5, 8, 51, 52, 60})
# frozenset({0, 1, 225, 5, 38, 165, 8, 13, 50})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 3, 5, 8, 42, 13, 175, 49, 243, 255})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 2, 4, 8, 31})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 2, 4, 39, 8})
# frozenset({0, 65, 2, 5, 8, 51, 52, 61})
# frozenset({0, 1, 5, 71, 8, 9, 48, 51})
# frozenset({0, 1, 5, 71, 8, 9, 48, 51})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 40, 13, 49, 244, 180})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 4, 5, 6, 8, 13, 57})
# frozenset({0, 1, 5, 7, 42})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 2, 3, 5, 8, 57})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 2, 3, 5, 7, 8, 44, 47, 58, 60})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 5, 8, 41, 234, 169, 13, 50, 246})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 38, 8})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 41, 13, 50, 180, 248})
# frozenset({0, 1, 65, 5, 8, 9, 48, 89})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 3, 5, 6, 39, 8, 41, 47, 29})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 4, 8, 58})
# frozenset({0, 1, 69, 10, 24})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 193, 5, 8, 265, 44, 13, 49})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 37, 8, 234, 172, 13, 49})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 2, 5, 8, 51, 52, 57, 61})
# frozenset({0, 1, 2, 3, 5, 8, 57})
# frozenset({0, 1, 2, 5, 11, 52})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 2, 3, 5, 8, 397, 47, 599, 88, 601})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 3, 5, 8, 14, 48, 17})
# frozenset({0, 192, 2, 259, 5, 8, 13, 50, 247, 30})
# frozenset({0, 1, 227, 164, 5, 39, 8, 13, 50})
# frozenset({0, 1, 227, 5, 8, 72, 13, 49, 338})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 2, 5, 37, 8, 265, 13, 49, 253, 191})
# frozenset({0, 1, 5, 70, 8, 9, 48, 50})
# frozenset({0, 1, 2, 4, 5, 38, 8, 48, 31})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 5, 38, 8, 267, 13, 50, 190, 255})
# frozenset({0, 2, 3, 5, 37, 39, 8, 47, 29})
# frozenset({0, 1, 6, 9, 48})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 198, 8, 72, 301, 13, 49})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 13, 50, 180, 279, 59})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 3, 5, 8, 46, 47, 19, 86})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 2, 5, 261, 8, 41, 13, 49, 273, 189})
# frozenset({0, 1, 5, 9, 55})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 257, 2, 5, 39, 8, 13, 49, 245, 183})
# frozenset({0, 2, 4, 5, 8, 50, 52, 59, 63})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 3, 5, 8, 41, 47, 31})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 2, 5, 39, 8, 13, 239, 176, 49, 251})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 10, 49})
# frozenset({0, 33, 2, 3, 5, 8, 105, 107, 47, 49})
# frozenset({0, 1, 68, 5, 7, 8, 48, 52})
# frozenset({0, 2, 5, 70, 8, 9, 74, 48, 50})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 260, 5, 8, 41, 13, 50, 182, 248})
# frozenset({0, 1, 195, 5, 8, 265, 42, 13, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 3, 5, 8, 41, 13, 240, 50, 178, 252})
# frozenset({0, 1, 2, 5, 8, 52, 58, 62})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 1, 3, 5, 8, 41, 47, 29})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 3, 5, 37, 39, 8, 47, 29})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 2, 5, 263, 8, 13, 45, 49, 180, 251})
# frozenset({0, 2, 5, 8, 266, 44, 13, 50, 183, 254})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 2, 258, 5, 8, 40, 13, 270, 49, 190})
# frozenset({0, 1, 97, 5, 8, 168, 52})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 2, 5, 8, 52, 53, 59, 63})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 71, 8, 9, 48, 52})
# frozenset({0, 1, 5, 231, 8, 39, 169, 13, 50})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 47, 52, 57})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 41, 13, 175, 241, 50})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 38, 8, 232, 171, 13, 50})
# frozenset({0, 1, 70, 9, 24})
# frozenset({0, 2, 5, 70, 8, 74, 48, 52})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 8, 24, 57})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 32, 2, 3, 34, 5, 8, 47, 20})
# frozenset({0, 2, 5, 71, 8, 9, 75, 48, 52})
# frozenset({0, 2, 67, 5, 7, 8, 49, 52, 63})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 5, 8, 75, 12, 79, 48, 51})
# frozenset({0, 1, 35, 5, 167, 8, 13, 50, 223})
# frozenset({0, 33, 2, 1, 5, 8, 48, 19})
# frozenset({0, 1, 5, 8, 47, 52, 53})
# frozenset({0, 1, 3, 5, 8, 42, 13, 175, 50, 242, 254})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 3, 5, 8, 17, 57, 25})
# frozenset({0, 2, 5, 231, 8, 41, 168, 13, 49, 243})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 42, 13, 50, 186, 255})
# frozenset({0, 1, 3, 5, 6, 8, 57})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 64, 2, 68, 5, 8, 47, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 5, 7, 8, 46, 52, 59, 63})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 5, 71, 8, 10, 75, 48, 50})
# frozenset({0, 1, 4, 5, 25})
# frozenset({0, 1, 11, 81, 24})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 5, 8, 74, 11, 78, 48, 51})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 2, 260, 5, 8, 41, 13, 272, 50, 191})
# frozenset({0, 1, 64, 5, 7, 8, 48})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 257, 2, 36, 5, 8, 13, 49, 245, 186})
# frozenset({0, 1, 2, 5, 8, 52, 59})
# frozenset({0, 2, 5, 6, 8, 73, 77, 52, 59})
# frozenset({0, 2, 68, 5, 7, 8, 72, 48, 52})
# frozenset({0, 1, 73, 10, 24})
# frozenset({0, 32, 2, 3, 5, 6, 8, 44, 46, 47})
# frozenset({0, 1, 4, 5, 26})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 2, 259, 5, 8, 41, 13, 50, 181, 247})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 49, 24})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 2, 5, 8, 78, 14, 48, 50, 82})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 5, 8, 13, 46, 50, 149, 219})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 27, 169, 13, 49, 219})
# frozenset({0, 1, 2, 3, 5, 8, 57})
# frozenset({0, 1, 5, 37, 8, 13, 50, 218, 158})
# frozenset({0, 2, 5, 8, 42, 267, 13, 49, 186, 255})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 192, 5, 8, 265, 43, 13, 50})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 2, 5, 39, 8, 13, 176, 49, 243, 255})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 4, 8, 52})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 65, 2, 1, 5, 8, 48, 29, 30})
# frozenset({0, 1, 5, 8, 49, 52, 55})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 89, 2, 1, 5, 8, 48, 57, 28})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 8, 54, 24})
# frozenset({0, 1, 2, 5, 11, 55})
# frozenset({0, 2, 3, 5, 8, 47, 16, 91, 93, 62})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 33, 5, 6})
# frozenset({0, 1, 5, 8, 76, 13, 48, 51})
# frozenset({0, 1, 3, 4, 5, 8, 40, 47, 31})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 32, 3, 5, 6, 8, 44, 47})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 35, 3, 5, 4, 37, 8, 47, 28})
# frozenset({0, 1, 71, 9, 24})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 163, 5, 8, 233, 13, 45, 50, 245})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 2, 5, 9, 47})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 66, 5, 8, 48, 51})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 323, 5, 70, 8, 13, 49, 210, 311})
# frozenset({0, 32, 2, 3, 5, 6, 8, 44, 46, 47})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 4, 5, 8, 49, 52, 59})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 5, 8, 73, 43, 77, 18, 52})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 66, 5, 70, 8, 48})
# frozenset({0, 1, 5, 9, 52})
# frozenset({0, 1, 5, 8, 48, 52, 59})
# frozenset({0, 1, 3, 67, 5, 7, 8, 71, 48, 51})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 162, 36, 5, 8, 13, 49, 219})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 2, 5, 8, 40, 265, 13, 50, 185, 253})
# frozenset({0, 1, 2, 5, 8, 52, 58, 62})
# frozenset({0, 2, 5, 37, 231, 8, 171, 13, 49, 243})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 160, 5, 8, 235, 13, 50, 51})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 2, 5, 8, 73, 10, 77, 48, 51})
# frozenset({0, 1, 66, 5, 8, 106, 48, 22})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 5, 8, 267, 13, 46, 49, 183, 255})
# frozenset({0, 1, 195, 5, 8, 13, 49, 53, 280})
# frozenset({0, 33, 2, 5, 7, 8, 47, 48, 51})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 2, 5, 8, 51, 52, 58})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 2, 66, 5, 8, 48, 113, 117, 24})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 41, 23})
# frozenset({0, 2, 5, 8, 73, 10, 77, 48, 51})
# frozenset({0, 1, 5, 8, 13, 45, 156, 50, 220})
# frozenset({0, 1, 5, 69, 7, 8, 52, 53})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 2, 5, 69, 13})
# frozenset({0, 1, 2, 4, 39, 8})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 161, 2, 36, 5, 231, 8, 13, 50, 219})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 2, 5, 39, 8, 13, 240, 177, 50, 252})
# frozenset({0, 2, 5, 8, 171, 44, 13, 238, 49, 250})
# frozenset({0, 1, 5, 8, 78, 14, 48, 50})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 2, 68, 5, 13})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 3, 5, 8, 13, 47, 80, 115, 117})
# frozenset({0, 2, 5, 6, 8, 43, 52, 54, 58})
# frozenset({0, 2, 5, 8, 41, 265, 13, 49, 188, 253})
# frozenset({0, 1, 34, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 4, 8, 52})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 4, 5, 8, 52, 63})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 14, 55, 57, 30})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 170, 13, 49, 50, 249})
# frozenset({0, 2, 3, 5, 37, 39, 8, 47, 29})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 35, 4, 6})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 260, 5, 8, 42, 13, 49, 181, 248})
# frozenset({32, 1, 0, 5, 6})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 33, 5, 8, 74, 52, 118})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 2, 5, 8, 107, 111, 48, 19, 63})
# frozenset({0, 1, 5, 71, 8, 10, 48, 50})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 228, 5, 39, 8, 168, 13, 50})
# frozenset({0, 1, 2, 5, 8, 47, 52, 55})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 5, 8, 140, 144, 52, 28, 95})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 81, 18, 51, 52})
# frozenset({0, 2, 67, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 5, 8, 40, 13, 238, 173, 50})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 66, 2, 6, 13})
# frozenset({0, 1, 3, 5, 7, 8, 47, 52, 59, 63})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 9, 52})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 2, 5, 11, 60})
# frozenset({0, 2, 36, 5, 167, 8, 234, 13, 50, 222})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 4, 5, 8, 46, 52, 55})
# frozenset({0, 1, 5, 8, 42, 13, 173, 239, 49})
# frozenset({0, 1, 5, 70, 8, 48, 52})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 3, 5, 8, 57})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 70, 8, 9, 48, 50})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 10, 59})
# frozenset({0, 1, 5, 8, 13, 49, 215, 59, 319})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 67, 5, 6, 8, 48, 52})
# frozenset({0, 2, 5, 37, 8, 236, 13, 50, 179, 248})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 2, 5, 9, 52})
# frozenset({0, 1, 5, 9, 61})
# frozenset({0, 1, 34, 4, 6})
# frozenset({0, 1, 5, 6, 8, 45, 52, 58})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 5, 8, 44, 13, 175, 50, 242, 254})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 32, 2, 3, 5, 6, 8, 44, 46, 47})
# frozenset({0, 2, 3, 5, 8, 47, 80, 16, 82})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 32, 2, 3, 5, 8, 42, 44, 47})
# frozenset({0, 1, 2, 4, 5, 8, 48})
# frozenset({0, 1, 2, 5, 8, 47, 52, 53, 57})
# frozenset({0, 1, 256, 36, 5, 196, 8, 13, 50})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 5, 8, 40, 13, 177, 50, 242, 254})
# frozenset({0, 1, 5, 8, 40, 13, 50, 180, 252})
# frozenset({0, 1, 2, 5, 8, 41, 48, 21, 87})
# frozenset({0, 1, 196, 5, 263, 8, 39, 13, 49})
# frozenset({0, 2, 5, 8, 41, 13, 173, 239, 50, 251})
# frozenset({0, 65, 2, 5, 69, 7, 8, 52, 53})
# frozenset({0, 2, 5, 261, 8, 40, 13, 49, 184, 249})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 5, 8, 40, 42, 48, 93})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 2, 5, 165, 8, 232, 42, 13, 50, 244})
# frozenset({0, 1, 5, 70, 8, 9, 48, 50})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 42, 13, 239, 176, 50})
# frozenset({0, 1, 5, 230, 8, 40, 169, 13, 50})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 2, 5, 71, 8, 75, 52, 54})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 2, 5, 10, 51})
# frozenset({0, 2, 5, 8, 40, 13, 239, 176, 49, 251})
# frozenset({0, 2, 5, 70, 8, 9, 74, 48, 50})
# frozenset({0, 1, 3, 227, 5, 36, 8, 171, 13, 239, 49})
# frozenset({0, 2, 5, 167, 8, 233, 43, 13, 50, 245})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 6, 30})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 260, 5, 8, 42, 13, 50, 190})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 5, 70, 8, 9, 74, 48, 50})
# frozenset({0, 1, 33, 4, 6})
# frozenset({0, 2, 5, 37, 8, 235, 13, 175, 49, 247})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 6, 13, 63})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 2, 35, 4, 7})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 7, 50, 23})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 38, 8, 13, 50, 182, 247})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 2, 5, 38, 231, 8, 169, 13, 50, 243})
# frozenset({0, 320, 2, 227, 5, 8, 332, 13, 49, 52})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 2, 5, 10, 48})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 2, 67, 5, 8, 47, 48, 147, 151})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 33, 5, 6})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 10, 61})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 33, 2, 3, 5, 8, 47, 51, 93, 95})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 70, 8, 48, 52})
# frozenset({0, 1, 5, 9, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 2, 5, 8, 169, 236, 13, 45, 50, 248})
# frozenset({0, 1, 2, 5, 8, 51, 52, 57, 61})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 40, 13, 50, 243, 179})
# frozenset({0, 1, 2, 5, 8, 12, 48, 56, 29})
# frozenset({0, 1, 67, 5, 8, 112, 52, 24})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 2, 35, 3, 5, 4, 37, 8, 47, 28})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 37, 8, 237, 13, 173, 50})
# frozenset({0, 1, 72, 10, 24})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 45, 84, 57, 28})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 3, 5, 6, 39, 8, 41, 47, 29})
# frozenset({0, 2, 3, 5, 8, 9, 46, 47, 48, 31})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 4, 8, 48})
# frozenset({0, 2, 260, 5, 38, 8, 13, 50, 248, 188})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 161, 2, 36, 5, 229, 8, 13, 50, 217})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 64, 2, 68, 5, 7, 8, 48})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 5, 8, 41, 13, 49, 188, 253})
# frozenset({0, 65, 2, 5, 69, 8, 48})
# frozenset({0, 1, 257, 5, 8, 43, 13, 50, 185})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 33, 4, 6})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 69, 10, 24})
# frozenset({0, 1, 5, 39, 8, 13, 49, 186, 253})
# frozenset({0, 1, 2, 5, 8, 43})
# frozenset({0, 1, 5, 229, 38, 8, 168, 13, 50})
# frozenset({0, 225, 2, 163, 5, 8, 40, 13, 237, 49})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 2, 5, 39, 8, 13, 173, 239, 50, 251})
# frozenset({0, 1, 227, 5, 38, 165, 8, 13, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 48, 54, 27, 94})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 34, 5, 8, 234, 13, 49, 178})
# frozenset({0, 225, 2, 5, 8, 44, 13, 237, 50, 156})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 71, 8, 9, 48, 51})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 4, 7, 40})
# frozenset({0, 2, 5, 166, 8, 235, 13, 46, 50, 247})
# frozenset({0, 2, 5, 71, 8, 10, 75, 48, 50})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 67, 5, 8, 9, 48})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 5, 6, 8, 72, 76, 52, 56})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 67, 5, 7, 8, 48, 51})
# frozenset({0, 1, 2, 5, 75, 13})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 3, 5, 6, 39, 8, 41, 47, 29})
# frozenset({0, 1, 2, 4, 39, 8})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 1, 65, 5, 8, 48})
# frozenset({0, 2, 3, 5, 8, 45, 52, 53, 57})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 3, 5, 6, 39, 8, 41, 47, 29})
# frozenset({0, 1, 5, 70, 8, 9, 48, 50})
# frozenset({0, 1, 5, 10, 52})
# frozenset({0, 1, 5, 9, 61})
# frozenset({0, 1, 67, 5, 8, 9, 48})
# frozenset({0, 1, 5, 8, 50, 52, 56})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 2, 34, 5, 263, 8, 13, 50, 251, 188})
# frozenset({0, 2, 772, 5, 8, 426, 13, 784, 50, 216})
# frozenset({0, 65, 2, 5, 8, 9, 48, 89, 93})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 35, 260, 5, 199, 8, 13, 272, 50})
# frozenset({0, 2, 4, 5, 69, 8, 73, 52, 58})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 5, 69, 6, 8, 52, 54})
# frozenset({0, 1, 5, 8, 43})
# frozenset({0, 1, 256, 5, 8, 13, 45, 49, 182})
# frozenset({0, 1, 5, 7, 42})
# frozenset({0, 1, 4, 5, 8, 14, 48})
# frozenset({0, 2, 67, 5, 7, 8, 71, 48, 51})
# frozenset({0, 64, 2, 68, 5, 8, 47, 48})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 41, 13, 49, 183, 248})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 4, 8, 46})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 3, 5, 8, 40, 107, 47, 55})
# frozenset({0, 2, 5, 8, 40, 236, 13, 174, 49, 248})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 2, 3, 5, 8, 57})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 64, 2, 68, 5, 8, 47, 48})
# frozenset({0, 1, 2, 4, 10, 45})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 5, 8, 110, 48, 114, 21, 62})
# frozenset({0, 1, 32, 3, 65, 5, 8, 47, 112})
# frozenset({0, 2, 228, 5, 37, 8, 168, 13, 240, 50})
# frozenset({0, 1, 3, 4, 5, 8, 40, 47, 31})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 66, 5, 262, 8, 171, 13, 50})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 108, 48, 24, 63})
# frozenset({0, 1, 33, 5, 6})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 5, 7, 8, 47, 48, 63})
# frozenset({0, 2, 259, 5, 8, 42, 13, 49, 177, 247})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 68, 9, 24})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 71, 8, 10, 48, 50})
# frozenset({0, 1, 4, 9, 57})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 3, 35, 5, 8, 42, 48})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 1, 2, 5, 70, 14})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 10, 54})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 5, 8, 48, 179, 122, 29})
# frozenset({0, 1, 2, 64, 5, 8, 47, 48, 127})
# frozenset({0, 1, 5, 7, 40})
# frozenset({0, 1, 5, 8, 73, 139, 48})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 6, 49, 24})
# frozenset({0, 1, 72, 11, 25})
# frozenset({0, 1, 5, 9, 50})
# frozenset({0, 1, 3, 5, 8, 46, 52, 54})
# frozenset({0, 1, 71, 10, 24})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 4, 8, 47})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 32, 3, 5, 6, 8, 44, 47})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 2, 5, 10, 51})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 65, 2, 1, 32, 5, 8, 48, 27})
# frozenset({0, 1, 258, 5, 8, 41, 13, 50, 191})
# frozenset({0, 2, 3, 5, 8, 41, 9, 43, 47, 28})
# frozenset({0, 2, 5, 37, 8, 233, 13, 173, 49, 245})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 195, 5, 8, 264, 43, 13, 50})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 10, 54})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 2, 5, 8, 40, 13, 238, 175, 49, 250})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 3, 5, 6, 39, 8, 47, 29})
# frozenset({0, 2, 5, 37, 8, 13, 238, 175, 49, 250})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 72, 10, 24})
# frozenset({0, 1, 5, 70, 8, 42, 12, 48})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 49, 52, 55})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 2, 259, 5, 8, 13, 46, 271, 50, 188})
# frozenset({0, 1, 3, 5, 8, 41, 47, 31})
# frozenset({0, 1, 5, 8, 49, 52, 56})
# frozenset({0, 289, 2, 5, 38, 8, 13, 301, 49, 219})
# frozenset({0, 2, 259, 5, 8, 43, 13, 176, 49, 247})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 43, 13, 15, 57})
# frozenset({0, 2, 5, 39, 8, 233, 171, 13, 50, 245})
# frozenset({0, 1, 4, 8, 48})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 2, 260, 5, 8, 40, 13, 50, 183, 248})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 73, 10, 48, 51})
# frozenset({0, 1, 5, 8, 41, 172, 13, 238, 49})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 3, 5, 8, 47, 52, 55})
# frozenset({0, 1, 35, 5, 8, 235, 13, 50, 181})
# frozenset({0, 1, 5, 295, 8, 204, 13, 49, 52})
# frozenset({0, 1, 5, 6, 8, 47, 52, 58})
# frozenset({0, 2, 3, 5, 37, 39, 8, 47, 29})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 2, 68, 5, 4, 8, 72, 52, 55})
# frozenset({0, 256, 2, 5, 8, 268, 13, 49, 50, 177})
# frozenset({0, 1, 32, 3, 5, 8, 74, 47, 121})
# frozenset({0, 1, 5, 8, 46, 48, 119, 58})
# frozenset({0, 1, 6, 9, 49})
# frozenset({0, 257, 2, 5, 38, 8, 13, 50, 245, 183})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 5, 70, 8, 74, 48, 52})
# frozenset({0, 1, 3, 5, 37, 8, 47, 29})
# frozenset({0, 2, 66, 4, 5, 8, 79, 83, 52})
# frozenset({0, 96, 2, 100, 5, 8, 52, 58, 28})
# frozenset({0, 2, 195, 292, 5, 8, 13, 50, 280, 58})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 67, 5, 7, 8, 71, 48, 51})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 259, 5, 8, 41, 13, 50, 247, 183})
# frozenset({0, 1, 32, 3, 5, 8, 42, 47})
# frozenset({0, 2, 68, 5, 8, 72, 52, 53})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 2, 5, 37, 8, 264, 13, 49, 252, 189})
# frozenset({0, 1, 5, 38, 8, 236, 13, 175, 50})
# frozenset({0, 191, 2, 5, 39, 8, 267, 13, 50, 255})
# frozenset({0, 1, 257, 5, 8, 42, 13, 50, 183})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 2, 4, 39, 8})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 2, 228, 5, 8, 43, 13, 50, 151, 216})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 2, 5, 8, 48, 54, 27, 94})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 224, 2, 161, 5, 39, 8, 236, 13, 50})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 197, 8, 43, 13, 50, 275})
# frozenset({0, 1, 5, 8, 43, 13, 50, 178, 246})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 2, 5, 37, 8, 13, 50, 243, 183, 255})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 32, 2, 3, 5, 8, 42, 44, 47})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 32, 35, 5, 8, 75, 48})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 48, 52, 55})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 40, 22, 87, 57})
# frozenset({0, 2, 3, 66, 5, 8, 52, 53, 62})
# frozenset({0, 65, 2, 5, 69, 8, 48})
# frozenset({0, 1, 5, 37, 8, 237, 13, 49, 178})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 2, 5, 39, 8, 232, 171, 13, 50, 244})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 2, 36, 5, 261, 8, 13, 49, 249, 189})
# frozenset({0, 1, 7, 53, 24})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 2, 5, 38, 8, 13, 239, 176, 50, 251})
# frozenset({0, 2, 66, 5, 6, 70, 8, 48, 51})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 2, 5, 8, 43, 52, 55, 59})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 10, 55})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 2, 3, 4, 5, 8, 40, 42, 47, 31})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 2, 5, 8, 52, 53, 61})
# frozenset({0, 1, 5, 8, 170, 44, 13, 49, 245})
# frozenset({0, 1, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 5, 38, 8, 13, 49, 246, 183})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 65, 2, 322, 5, 8, 13, 206, 49, 310})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 5, 39, 8, 13, 238, 174, 49, 250})
# frozenset({0, 1, 3, 5, 37, 8, 47, 29})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 8, 24, 59})
# frozenset({0, 2, 5, 8, 44, 52, 58, 62})
# frozenset({0, 1, 64, 5, 8, 48, 115, 27})
# frozenset({0, 1, 35, 5, 8, 42, 48, 89})
# frozenset({0, 1, 72, 10, 24})
# frozenset({0, 2, 5, 8, 40, 13, 174, 240, 49, 252})
# frozenset({0, 2, 68, 5, 7, 8, 72, 48, 52})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 194, 5, 261, 8, 43, 13, 49})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 4, 5, 8, 14, 48})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 2, 5, 8, 48, 52, 58, 62})
# frozenset({0, 2, 66, 5, 70, 8, 48})
# frozenset({0, 1, 5, 38, 8, 186, 13, 50, 250})
# frozenset({0, 1, 68, 5, 8, 48})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 8, 24, 60})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 66, 9, 24})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 7, 41})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 2, 258, 5, 8, 44, 13, 49, 178, 246})
# frozenset({0, 1, 5, 7, 41})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 37, 8, 13, 240, 49, 178})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 1, 2, 5, 8, 73, 48, 26, 28})
# frozenset({0, 2, 5, 37, 262, 8, 13, 49, 250, 188})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 2, 5, 10, 56})
# frozenset({0, 1, 32, 3, 5, 8, 43, 47})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 2, 36, 5, 8, 13, 50, 242, 180, 254})
# frozenset({0, 1, 196, 5, 8, 266, 42, 13, 49})
# frozenset({0, 1, 5, 229, 38, 8, 170, 13, 50})
# frozenset({0, 2, 5, 165, 8, 13, 49, 241, 50, 253})
# frozenset({0, 1, 33, 5, 6})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 807, 8, 13, 239, 433, 50})
# frozenset({0, 1, 5, 8, 204, 13, 46, 49, 275})
# frozenset({0, 2, 67, 5, 7, 8, 71, 48, 51})
# frozenset({0, 1, 6, 45, 23})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 5, 8, 13, 48, 49, 178, 251})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 6, 8, 11, 57, 25})
# frozenset({0, 2, 36, 5, 261, 197, 8, 13, 273, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 32, 2, 3, 5, 6, 8, 44, 46, 47})
# frozenset({0, 2, 260, 5, 8, 44, 13, 50, 180, 248})
# frozenset({0, 1, 257, 36, 5, 197, 8, 13, 49})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 3, 5, 8, 57})
# frozenset({0, 1, 3, 5, 6, 39, 8, 47, 29})
# frozenset({0, 1, 5, 8, 52, 57, 63})
# frozenset({0, 1, 4, 8, 52})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 65, 5, 8, 48})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 5, 71, 8, 10, 75, 48, 50})
# frozenset({0, 1, 2, 5, 71, 13})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 2, 5, 8, 9, 12, 48})
# frozenset({0, 1, 71, 10, 24})
# frozenset({0, 2, 5, 263, 8, 13, 45, 49, 179, 251})
# frozenset({0, 1, 68, 5, 8, 48, 51})
# frozenset({32, 1, 0, 4, 5})
# frozenset({0, 2, 5, 38, 8, 13, 49, 242, 178, 254})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 46, 52, 56})
# frozenset({0, 1, 5, 8, 41, 13, 49, 218, 155})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 2, 5, 8, 13, 209, 50, 307, 57, 319})
# frozenset({0, 1, 65, 5, 8, 10, 50, 52})
# frozenset({0, 1, 32, 3, 5, 8, 42, 47})
# frozenset({0, 1, 5, 37, 8, 13, 238, 50, 179})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 2, 5, 165, 8, 232, 43, 13, 50, 244})
# frozenset({0, 64, 2, 3, 5, 8, 52, 60})
# frozenset({0, 1, 68, 5, 7, 8, 48, 52})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 2, 5, 69, 8, 73, 48, 52})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 36, 5, 8, 13, 240, 49, 183, 252})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 5, 9, 47})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 9, 53})
# frozenset({0, 2, 259, 5, 39, 8, 13, 49, 182, 247})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 2, 5, 8, 73, 10, 77, 48, 51})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 320, 2, 5, 8, 13, 49, 82, 308, 191})
# frozenset({0, 1, 3, 5, 8, 14, 48, 17})
# frozenset({0, 2, 5, 69, 8, 73, 48, 50})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 76, 12, 48, 50})
# frozenset({0, 1, 5, 8, 43})
# frozenset({0, 2, 5, 8, 73, 10, 77, 48, 51})
# frozenset({0, 1, 2, 5, 9, 47})
# frozenset({0, 2, 3, 5, 8, 13, 110, 47, 77, 112})
# frozenset({0, 1, 5, 8, 13, 49, 273, 52, 188})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 2, 5, 8, 77, 13, 48, 81, 50})
# frozenset({0, 192, 2, 68, 5, 293, 8, 13, 305, 50})
# frozenset({0, 2, 5, 71, 8, 10, 75, 48, 50})
# frozenset({0, 2, 4, 5, 8, 49, 52, 59, 63})
# frozenset({0, 1, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 66, 5, 8, 49, 52})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 257, 2, 5, 197, 8, 40, 13, 269, 49})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 3, 5, 8, 41, 47, 31})
# frozenset({0, 1, 5, 8, 44, 13, 49, 178, 247})
# frozenset({0, 1, 34, 3, 5, 8, 47, 28})
# frozenset({0, 1, 5, 165, 8, 235, 13, 46, 50})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 2, 4, 8, 31})
# frozenset({0, 2, 67, 5, 7, 8, 71, 48, 51})
# frozenset({0, 1, 256, 5, 8, 13, 49, 181})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 2, 226, 164, 5, 39, 8, 13, 238, 49})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 68, 5, 8, 10, 48})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 2, 4, 5, 8, 15, 48, 22})
# frozenset({0, 2, 3, 5, 8, 50, 52, 58, 62})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 41, 13, 49, 221, 158})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 256, 2, 5, 8, 42, 268, 13, 50, 186})
# frozenset({0, 1, 5, 8, 10, 76, 48, 55})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 2, 162, 5, 8, 41, 235, 13, 49, 223})
# frozenset({0, 1, 3, 5, 262, 39, 8, 13, 50, 185, 250})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 5, 8, 50})
# ...
# frozenset({0, 1, 5, 229, 39, 8, 165, 13, 49})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 5, 8, 76, 12, 48, 50})
# frozenset({0, 2, 5, 229, 39, 8, 13, 50, 217, 156})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 4, 5, 70, 8, 52, 58})
# frozenset({0, 2, 66, 5, 70, 8, 48})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 67, 5, 6, 8, 48, 52})
# frozenset({0, 256, 2, 192, 5, 8, 40, 268, 13, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 42, 52, 53})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 71, 8, 9, 48, 52})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 39, 8, 169, 234, 13, 50})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 2, 5, 74, 14})
# frozenset({0, 2, 67, 5, 7, 8, 71, 48, 51})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 41, 13, 177, 50, 242})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 2, 5, 11, 62})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 2, 3, 4, 5, 8, 40, 42, 47, 31})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 4, 7, 55})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 66, 5, 6, 8, 48, 51})
# frozenset({0, 2, 226, 5, 37, 167, 8, 13, 238, 50})
# frozenset({0, 1, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 2, 5, 8, 43, 13, 177, 50, 243, 255})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 32, 3, 5, 8, 42, 47})
# frozenset({0, 1, 2, 3, 5, 8, 57})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 1, 5, 8, 170, 13, 238, 47, 49})
# frozenset({0, 2, 258, 5, 8, 40, 13, 50, 246, 183})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 5, 69, 13})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 13, 49, 311, 58, 220})
# frozenset({0, 1, 3, 5, 70, 8, 9, 74, 48, 50})
# frozenset({0, 2, 4, 5, 8, 48, 52, 57, 61})
# frozenset({0, 1, 2, 34, 5, 8, 77, 21, 57})
# frozenset({0, 1, 5, 38, 8, 74, 48, 127})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 2, 185, 36, 5, 261, 8, 13, 49, 249})
# frozenset({0, 1, 5, 8, 40, 13, 49, 242, 180})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 4, 5, 8, 52, 62})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 5, 8, 47, 16, 18, 57})
# frozenset({0, 2, 5, 229, 8, 44, 13, 49, 241, 159})
# frozenset({0, 2, 3, 5, 37, 39, 8, 47, 29})
# frozenset({0, 97, 2, 3, 99, 5, 37, 8, 47, 51})
# frozenset({0, 1, 5, 8, 41, 79, 57, 28})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 65, 1, 2, 5, 11})
# frozenset({0, 1, 5, 8, 52, 54, 61})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 2, 5, 261, 8, 43, 13, 50, 182, 249})
# frozenset({0, 1, 5, 8, 47, 52, 53})
# frozenset({0, 2, 5, 39, 8, 13, 49, 243, 180, 255})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 2, 35, 4, 7})
# frozenset({0, 1, 5, 41, 23})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 2, 5, 38, 8, 232, 172, 13, 49, 244})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 7, 8, 47, 48, 63})
# frozenset({0, 2, 67, 5, 71, 8, 10, 49, 52})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 3, 5, 37, 8, 47, 29})
# frozenset({0, 1, 2, 4, 5, 38, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 48, 52, 58})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 5, 8, 40, 13, 175, 240, 49, 252})
# frozenset({0, 1, 5, 37, 8, 13, 238, 176, 50})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 2, 5, 8, 74, 11, 78, 48, 51})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 35, 3, 5, 4, 8, 47, 28})
# frozenset({0, 1, 5, 229, 8, 44, 13, 49, 159})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 2, 34, 32, 5, 8, 48})
# frozenset({0, 1, 66, 5, 8, 48})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 5, 8, 42, 172, 13, 241, 50, 253})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 5, 8, 46, 52, 53})
# frozenset({0, 1, 5, 8, 170, 43, 13, 240, 49})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 3, 5, 8, 41, 47, 31})
# frozenset({0, 1, 3, 5, 8, 45, 47, 90, 27})
# frozenset({0, 1, 3, 5, 8, 41, 47, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 35, 5, 229, 8, 172, 13, 49, 241})
# frozenset({0, 2, 3, 5, 6, 39, 8, 41, 47, 29})
# frozenset({0, 1, 5, 8, 169, 13, 46, 241, 50})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 2, 5, 8, 73, 10, 77, 48, 51})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 40, 13, 187, 50, 251})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 4, 38, 7})
# frozenset({0, 1, 68, 5, 8, 20, 57, 29})
# frozenset({0, 2, 5, 39, 8, 235, 13, 175, 49, 247})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 46, 48, 119, 58})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 256, 2, 5, 8, 41, 13, 50, 244, 181})
# frozenset({0, 1, 5, 9, 52})
# frozenset({0, 1, 5, 8, 48, 17, 61, 30})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 65, 5, 8, 48})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 2, 5, 8, 41, 233, 13, 50, 221, 159})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 36, 5, 8, 13, 49, 242, 180})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 4, 7, 31})
# frozenset({0, 1, 64, 5, 8, 9, 48, 84})
# frozenset({0, 1, 5, 7, 42})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 2, 5, 11, 62})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 39, 8, 13, 50, 180, 245})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 41, 13, 50, 218, 155})
# frozenset({0, 2, 67, 5, 8, 52, 116, 22, 120})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 5, 8, 51, 52, 57})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 3, 5, 8, 46, 52, 55, 59})
# frozenset({0, 1, 3, 5, 8, 41, 47, 31})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 32, 2, 3, 5, 6, 8, 44, 46, 47})
# frozenset({0, 1, 4, 5, 25})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 36, 5, 8, 13, 49, 241, 181, 253})
# frozenset({0, 1, 3, 5, 6, 39, 8, 47, 29})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 9, 52})
# frozenset({0, 1, 2, 4, 9, 41})
# frozenset({0, 2, 67, 5, 7, 8, 71, 48, 51})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 10, 45, 52, 62})
# frozenset({0, 1, 228, 5, 38, 8, 169, 13, 50})
# frozenset({0, 2, 68, 5, 8, 107, 111, 52, 23})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 131, 35, 5, 69, 8, 48})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 73, 10, 48, 51})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 2, 5, 37, 261, 8, 13, 49, 249, 187})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 5, 38, 8, 13, 49, 241, 181})
# frozenset({0, 1, 2, 5, 69, 8, 42, 15, 48})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 2, 5, 8, 47, 52, 55})
# frozenset({0, 1, 2, 5, 8, 15, 20, 57})
# frozenset({0, 64, 2, 68, 5, 8, 47, 48})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 72, 10, 48, 51})
# frozenset({0, 1, 64, 5, 8, 47, 48})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 128, 2, 132, 5, 8, 48, 19, 90})
# frozenset({0, 257, 2, 34, 195, 5, 8, 13, 269, 50})
# frozenset({0, 1, 3, 5, 6, 39, 8, 47, 29})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 3, 5, 6, 39, 8, 47, 29})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 2, 68, 5, 7, 8, 72, 48, 52})
# frozenset({0, 2, 67, 5, 7, 8, 71, 48, 51})
# frozenset({0, 224, 2, 5, 8, 44, 13, 236, 50, 157})
# frozenset({0, 1, 5, 8, 41, 13, 50, 187, 255})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 32, 2, 3, 5, 8, 47, 16, 58, 60})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 9, 52})
# frozenset({0, 1, 2, 5, 70, 13})
# frozenset({0, 1, 2, 5, 8, 48, 23, 30})
# frozenset({0, 2, 67, 5, 7, 8, 71, 48})
# frozenset({0, 2, 5, 8, 15, 48, 80, 52, 84})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 39, 8, 235, 13, 173, 49})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 2, 3, 5, 6, 39, 8, 41, 47, 29})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 71, 8, 10, 48, 50})
# frozenset({0, 1, 4, 5, 25})
# frozenset({0, 1, 67, 8, 24})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 32, 2, 3, 5, 8, 43, 45, 47})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 5, 8, 48, 16, 53, 24})
# frozenset({0, 2, 68, 5, 8, 72, 48, 51})
# frozenset({0, 1, 5, 8, 40, 48, 115, 61})
# frozenset({0, 1, 66, 5, 8, 48})
# frozenset({0, 2, 66, 5, 6, 70, 8, 48, 51})
# frozenset({0, 2, 5, 167, 8, 232, 44, 13, 49, 244})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 2, 258, 5, 8, 41, 13, 270, 50, 190})
# frozenset({0, 1, 5, 70, 8, 48, 52})
# frozenset({0, 1, 2, 5, 9, 52})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 2, 35, 5, 8, 13, 239, 50, 179, 251})
# frozenset({0, 1, 2, 5, 75, 13})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 198, 8, 13, 47, 49, 274})
# frozenset({0, 2, 5, 71, 8, 10, 75, 48, 50})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 15, 48, 18})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 5, 38, 8, 235, 13, 173, 50})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 1, 66, 9, 24})
# frozenset({0, 1, 4, 5, 25})
# frozenset({0, 2, 5, 8, 49, 52, 57, 61})
# frozenset({0, 2, 5, 8, 47, 52, 57, 61})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 3, 5, 8, 57})
# frozenset({0, 1, 6, 9, 48})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 257, 2, 5, 8, 41, 13, 49, 177, 245})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 5, 8, 46})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 70, 8, 9, 48, 51})
# frozenset({64, 1, 2, 0, 5, 12})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 8, 24, 61})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 13, 79, 49, 179, 285})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 4, 11, 78})
# frozenset({0, 1, 5, 39, 8, 13, 50, 186, 251})
# frozenset({0, 2, 67, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 2, 5, 8, 52, 58, 62})
# frozenset({0, 1, 3, 5, 8, 43, 47, 82, 20})
# frozenset({0, 1, 5, 8, 14, 48, 17})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 194, 5, 262, 39, 8, 13, 50})
# frozenset({0, 2, 5, 8, 40, 13, 238, 174, 50, 250})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 3, 5, 8, 398, 47, 591, 79, 593})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 2, 5, 8, 15, 48, 18})
# frozenset({0, 2, 5, 261, 8, 41, 13, 49, 273, 190})
# frozenset({0, 1, 2, 5, 8, 50, 52, 56, 60})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 39, 8, 232, 171, 13, 50})
# frozenset({0, 2, 5, 37, 8, 233, 13, 174, 49, 245})
# frozenset({0, 1, 2, 67, 5, 8, 48, 19, 29})
# frozenset({0, 1, 2, 5, 8, 14, 48, 17})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 129, 2, 5, 69, 133, 8, 44, 52})
# frozenset({0, 1, 72, 10, 24})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 51})
# frozenset({0, 1, 36, 5, 8, 13, 49, 244, 186})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 394, 48, 567, 61})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 3, 5, 6, 8, 47, 20, 30})
# frozenset({0, 1, 2, 5, 8, 47, 52, 53, 57})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 39, 8, 13, 49, 184, 250})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 8, 13, 47, 49, 181, 255})
# frozenset({0, 2, 3, 5, 6, 39, 8, 41, 47, 29})
# frozenset({0, 1, 5, 69, 8, 48, 52})
# frozenset({0, 96, 2, 3, 5, 8, 47, 16, 59, 94})
# frozenset({0, 1, 64, 5, 7, 8, 48, 49})
# frozenset({0, 1, 5, 10, 62})
# frozenset({0, 2, 5, 37, 8, 264, 13, 50, 252, 189})
# frozenset({0, 1, 5, 8, 50, 52, 56})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 2, 5, 8, 52, 58, 62})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 2, 5, 38, 8, 237, 13, 174, 49, 249})
# frozenset({0, 256, 2, 5, 39, 8, 13, 50, 179, 244})
# frozenset({0, 1, 2, 5, 8, 52, 53, 59, 63})
# frozenset({0, 193, 2, 5, 8, 264, 13, 45, 50, 276})
# frozenset({0, 1, 5, 9, 57})
# frozenset({0, 1, 3, 36, 5, 4, 8, 47, 29})
# frozenset({0, 33, 2, 1, 5, 8, 48, 31})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 5, 8, 73, 13, 205, 49, 315})
# frozenset({0, 2, 5, 70, 8, 9, 74, 48, 51})
# frozenset({0, 2, 35, 5, 229, 8, 171, 13, 49, 241})
# frozenset({0, 1, 5, 229, 37, 8, 169, 13, 50})
# frozenset({0, 2, 5, 37, 261, 8, 13, 50, 249, 190})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 2, 3, 5, 37, 39, 8, 47, 29})
# frozenset({0, 1, 2, 4, 8, 31})
# frozenset({0, 1, 5, 8, 172, 13, 46, 49, 247})
# frozenset({0, 2, 3, 5, 37, 39, 8, 47, 28})
# frozenset({0, 2, 36, 5, 8, 105, 109, 48, 58})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 2, 5, 39, 8, 171, 236, 13, 49, 248})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 4, 9, 77})
# frozenset({0, 1, 5, 37, 231, 8, 13, 173, 50})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 5, 167, 8, 233, 41, 13, 50})
# frozenset({0, 1, 226, 5, 166, 8, 40, 13, 50})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 2, 3, 36, 5, 38, 8, 47, 28})
# frozenset({0, 1, 5, 8, 56})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 69, 7, 8, 48, 52})
# frozenset({0, 1, 4, 7, 30})
# frozenset({0, 64, 2, 68, 5, 8, 47, 48})
# frozenset({0, 1, 4, 10, 61})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 2, 323, 5, 8, 13, 49, 311, 58, 220})
# frozenset({0, 2, 67, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 33, 5, 8, 48, 31})
# frozenset({0, 1, 2, 5, 8, 19, 22, 57})
# frozenset({0, 1, 5, 7, 8, 50, 52, 63})
# frozenset({0, 2, 3, 5, 8, 41, 43, 47, 31})
# frozenset({0, 1, 32, 3, 5, 8, 42, 47})
# frozenset({0, 32, 2, 3, 5, 8, 40, 42, 47})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 8, 47})
# frozenset({0, 1, 5, 8, 49})
# frozenset({0, 1, 2, 5, 13, 78})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 2, 4, 5, 8, 57})
# frozenset({0, 1, 3, 36, 5, 8, 47, 28})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 39, 8, 234, 172, 13, 50})
# frozenset({0, 1, 66, 3, 5, 8, 52, 56})
# frozenset({0, 1, 259, 195, 5, 39, 8, 13, 49})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 69, 8, 42, 15, 48})
# frozenset({0, 1, 5, 9, 58})
# frozenset({0, 1, 5, 7, 8, 47, 48, 63})
# frozenset({0, 1, 5, 8, 50})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 5, 7, 42})
# frozenset({0, 1, 3, 5, 38, 8, 13, 177, 50, 242, 254})
# frozenset({0, 1, 5, 8, 48})
# frozenset({0, 1, 5, 7, 39})
# frozenset({0, 1, 6, 8, 44})
# frozenset({0, 1, 34, 32, 5, 8, 48})
# frozenset({0, 1, 2, 5, 12, 60})
# frozenset({0, 2, 5, 101, 8, 616, 620, 398, 52})

# %%
# تعريف فئة Apriori
class Apriori:
    def __init__(self, file_path):
        # تحميل البيانات بدون رؤوس أعمدة
        self.data = pd.read_csv(file_path, header=None)

        # التحقق من تكرار أسماء الأعمدة وإعادة تسميتها إذا لزم الأمر
        if self.data.columns.duplicated().any():
            self.data.columns = [f'col_{i}' for i in range(self.data.shape[1])]

        # تحويل البيانات إلى شكل مناسب
        self.data = self.data.apply(lambda row: pd.Series({item: 1 for item in row.dropna().values}), axis=1).fillna(0)

    def run_apriori(self, min_freq):
        # حساب التكرارات باستخدام خوارزمية Apriori
        frequent_itemsets = apriori(self.data, min_support=min_freq, use_colnames=True)
        return frequent_itemsets

# تحميل البيانات
apriori_instance = Apriori(x_train_file_path)

# حساب التكرارات
frequent_itemsets = apriori_instance.run_apriori(min_freq=0.5)

# حساب قواعد الارتباط
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-202b5c409489> in <cell line: 26>()
#      24
#      25 # حساب قواعد الارتباط
# ---> 26 rules = association_rules(frequent_itemsets, min_threshold=0.7)
#
# TypeError: association_rules() missing 1 required positional argument: 'num_itemsets'

# %%
# عرض النتائج
print("مجموعات العناصر المتكررة:")
print(frequent_itemsets)

print("\nقواعد الارتباط:")
print(rules)

# %%
# إعداد البيانات للرسم
plt.figure(figsize=(12, 6))
sns.scatterplot(data=rules, x='support', y='confidence', size='lift', sizes=(20, 200), hue='lift', palette='viridis', alpha=0.6)

# %%
# الثقة مقابل الدعم

# تخصيص الرسم
plt.title('ثقة مقابل دعم قواعد الارتباط')
plt.xlabel('الدعم')
plt.ylabel('الثقة')
plt.axhline(0.7, color='red', linestyle='--', label='Threshold Confidence (0.7)')
plt.axvline(0.5, color='blue', linestyle='--', label='Threshold Support (0.5)')
plt.legend()
plt.grid()
plt.show()

# %%
# رسم الدعم مقابل الثقة
sns.scatterplot(x='support', y='confidence', data=rules)

# إضافة عنوان ووسوم المحاور
plt.title('Support vs Confidence for Association Rules')
plt.xlabel('Support')
plt.ylabel('Confidence')

# عرض الرسم
plt.grid()
plt.show()

# %%
# رسم الدعم مقابل الرفع
sns.scatterplot(x='support', y='lift', data=rules)

# إضافة عنوان ووسوم المحاور
plt.title('Support vs Lift for Association Rules')
plt.xlabel('Support')
plt.ylabel('Lift')

# عرض الرسم
plt.grid()
plt.show()
